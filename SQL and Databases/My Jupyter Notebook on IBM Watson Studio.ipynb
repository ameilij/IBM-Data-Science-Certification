# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Ariel E. Meilij__
#
# Data Scientist Student

# %% [markdown]
# Hello World! My name is Ariel Meilij and I live in _Panama_ (Central America.) I love data science and use analytical tools in my job to help my cowokers improve their skills at forecasting, business analytics, data story telling, and getting amazing data insights from __EDA__ (Exploratory Data Analysis) tools.

# %% [markdown]
# ### The following code gets the average of a small list of items. I love average, because I believe averages are our first introduction to descriptive statistics. They are also simple to understand, do not involve a lot of math, and sometimes tell a bigger story than other, more sophisticated formulas and algorithms.

# %%
def getAverage(n):
    return sum(n)/len(n)

getAverage([2,4,6,8,10])
# Out:
# 6.0

# %% [markdown]
# You can follow me around in the following websites:
#
# * My Twitter account at [Ariel Meilij Twitter](https://twitter.com/ameilij)
# * My code repository at [Ariel Meilij Github](https://github.com/ameilij)
# * My personal website at [The Complexity of Simplicity](http://meilij.com)
#
# In case you are wondering my favorite Data Science tools are:
#
# 1. RStudio
# 2. Jupyter Lab for Python notebooks
# 3. Julia
#
# ---------------------------------------------------------
#
# Some people ask me about my preference for DS languajes. I have some opinions but I think you should use whatever gets the job done and you love using.
#
# > I have long refrained from languaje wars and OS wars. I love R and Python in equal measure, but I am new to Julia.
#
# I also enjoy using Windows, Mac and Linux in equal measure. I might even use Chrome OS in the future given the great range of DS tools on the web such as **IBM Watson Studio**.
